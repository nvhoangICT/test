# %%
# !pip install easyocr

# %%
import matplotlib.pyplot as plt
import cv2
import easyocr
from pylab import rcParams
from IPython.display import Image
rcParams['figure.figsize'] = 8, 16

# %%
reader = easyocr.Reader(['vi'])

# %%
Image("bien-quang-cao-banh-mi-1.jpg")

# %%
output = reader.readtext('bien-quang-cao-banh-mi-1.jpg')

# %%
output
# Out:
# [([[115, 281], [571, 281], [571, 369], [115, 369]],
#   'BAMI KING',
#   0.5959642816669651),
#  ([[40, 366], [220, 366], [220, 398], [40, 398]],
#   '56 QUÁN THÁNH',
#   0.8061899943844412),
#  ([[516, 374], [650, 374], [650, 404], [516, 404]],
#   '1900 636 912',
#   0.967166591866845),
#  ([[11, 467], [39, 467], [39, 481], [11, 481]], 'Pho', 0.36154824532500424),
#  ([[207, 437], [617, 437], [617, 481], [207, 481]],
#   'VUA BÁNH MÌ BÒ NƯỚNG',
#   0.897876084621854),
#  ([[0, 478], [54, 478], [54, 502], [0, 502]], 'E NHAI', 0.08062336953779901),
#  ([[533, 712], [670, 712], [670, 761], [533, 761]],
#   'LASER',
#   0.9913557732660238),
#  ([[442, 752], [670, 752], [670, 776], [442, 776]],
#   "YOU SAY, WE'LL Do IT",
#   0.7138311830871749),
#  ([[489, 781], [529, 781], [529, 795], [489, 795]], 'WWW', 0.4151348121909586),
#  ([[529, 775], [627, 775], [627, 795], [529, 795]],
#   'O8laser com',
#   0.5996590383746455)]

# %%
cord = output[0][0]

# %%
x_min, y_min = [int(min(idx)) for idx in zip(*cord)]

# %%
x_max, y_max = [int(max(idx)) for idx in zip(*cord)]

# %%
image = cv2.imread('bien-quang-cao-banh-mi-1.jpg')
cv2.rectangle(image,(x_min,y_min),(x_max,y_max),(0,0,255),2)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
